# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/Covid Data.csv", encoding="latin-1")

# %%
data.head()
# Out:
#   Country  Total Cases  New Cases  Total Deaths  New Deaths  Total Recovered  \
# 0     USA      2890588        NaN      132101.0         NaN        1235488.0
# 1  Brazil      1543341        NaN       63524.0         NaN         978615.0
# 2  Russia       674515     6632.0       10027.0       168.0         446879.0
# 3   India       649889        NaN       18669.0         NaN         394411.0
# 4   Spain       297625        NaN       28385.0         NaN         150000.0
#
#    Active Cases  Serious/Critical Cases  Total Tests  Population
# 0     1522999.0                 15928.0   36297195.0   331018157
# 1      501472.0                  8318.0    3330562.0   212570544
# 2      217609.0                  2300.0   20451110.0   145935130
# 3      236809.0                  8944.0    9540132.0  1380085626
# 4           NaN                   617.0    5448984.0    46754972

# %%
data.columns
# Out:
# Index(['Country', 'Total Cases', 'New Cases', 'Total Deaths', 'New Deaths',
#        'Total Recovered', 'Active Cases', 'Serious/Critical Cases',
#        'Total Tests', 'Population'],
#       dtype='object')

# %%
data.tail()
# Out:
#                     Country  Total Cases  New Cases  Total Deaths  New Deaths  \
# 208  British Virgin Islands            8        NaN           1.0         NaN
# 209   Caribbean Netherlands            7        NaN           NaN         NaN
# 210               St. Barth            6        NaN           NaN         NaN
# 211                Anguilla            3        NaN           NaN         NaN
# 212   Saint Pierre Miquelon            1        NaN           NaN         NaN
#
#      Total Recovered  Active Cases  Serious/Critical Cases  Total Tests  \
# 208              7.0           0.0                     NaN        439.0
# 209              7.0           0.0                     NaN        424.0
# 210              6.0           0.0                     NaN        152.0
# 211              3.0           0.0                     NaN        272.0
# 212              1.0           0.0                     NaN          NaN
#
#      Population
# 208       30233
# 209       26225
# ...

# %%
data.describe()
# Out:
#         Total Cases    New Cases   Total Deaths  New Deaths  Total Recovered  \
# count  2.130000e+02    30.000000     183.000000   11.000000     2.100000e+02
# mean   5.261010e+04   796.033333    2894.306011   90.363636     2.999533e+04
# std    2.369667e+05  1749.685834   12161.366828  193.325256     1.203711e+05
# min    1.000000e+00     1.000000       1.000000    1.000000     1.000000e+00
# 25%    3.280000e+02     3.500000      15.000000    7.500000     1.830000e+02
# 50%    2.349000e+03   105.500000      74.000000   14.000000     1.320000e+03
# 75%    1.938800e+04   522.000000     605.500000   58.500000     1.100975e+04
# max    2.890588e+06  6740.000000  132101.000000  654.000000     1.235488e+06
#
#        Active Cases  Serious/Critical Cases   Total Tests    Population
# count  2.090000e+02              128.000000  1.930000e+02  2.130000e+02
# mean   1.869724e+04              459.507812  1.290396e+06  3.887653e+07
# ...

# %%
data.isnull().sum()
# Out:
# Country                     0
# Total Cases                 0
# New Cases                 183
# Total Deaths               30
# New Deaths                202
# Total Recovered             3
# Active Cases                4
# Serious/Critical Cases     85
# Total Tests                20
# Population                  0
# dtype: int64

# %%
data = data.fillna(0)

# %%
data.tail()
# Out:
#                     Country  Total Cases  New Cases  Total Deaths  New Deaths  \
# 208  British Virgin Islands            8        0.0           1.0         0.0
# 209   Caribbean Netherlands            7        0.0           0.0         0.0
# 210               St. Barth            6        0.0           0.0         0.0
# 211                Anguilla            3        0.0           0.0         0.0
# 212   Saint Pierre Miquelon            1        0.0           0.0         0.0
#
#      Total Recovered  Active Cases  Serious/Critical Cases  Total Tests  \
# 208              7.0           0.0                     0.0        439.0
# 209              7.0           0.0                     0.0        424.0
# 210              6.0           0.0                     0.0        152.0
# 211              3.0           0.0                     0.0        272.0
# 212              1.0           0.0                     0.0          0.0
#
#      Population
# 208       30233
# 209       26225
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Total Cases', 'New Cases', 'Total Deaths', 'New Deaths',
#        'Total Recovered', 'Active Cases', 'Serious/Critical Cases',
#        'Total Tests', 'Population'],
#       dtype='object')

# %% [markdown]
# # Relating the variables with scatterplots

# %%
sns.relplot(x= "Total Cases",y="Total Deaths",data= data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="Serious/Critical Cases",y="Total Cases",kind='line',data=data)

# %%
data.columns
# Out:
# Index(['Country', 'Total Cases', 'New Cases', 'Total Deaths', 'New Deaths',
#        'Total Recovered', 'Active Cases', 'Serious/Critical Cases',
#        'Total Tests', 'Population'],
#       dtype='object')

# %%
sns.catplot(x="Total Recovered",y="Active Cases",data= data)
