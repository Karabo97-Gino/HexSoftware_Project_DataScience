# %%
##Analyzing and Visualizing Movie Ratings

import pandas as pd
import numpy as np


data = pd.read_csv("/content/imdb-movies-dataset.csv")

# %%
data.head(10)
# Out:
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1  https://m.media-amazon.com/images/M/MV5BZGI4NT...
# 2  https://m.media-amazon.com/images/M/MV5BZjIyOT...
# 3  https://m.media-amazon.com/images/M/MV5BMjA5Zj...
# 4  https://m.media-amazon.com/images/M/MV5BNTk1MT...
# 5  https://m.media-amazon.com/images/M/MV5BY2JlYj...
# 6  https://m.media-amazon.com/images/M/MV5BYTYyOD...
# 7  https://m.media-amazon.com/images/M/MV5BZTc3Ym...
# 8  https://m.media-amazon.com/images/M/MV5BOTVhZG...
# 9  https://m.media-amazon.com/images/M/MV5BOWI5YT...
#
#                                    Title    Year Certificate  Duration (min)  \
# 0                        The Idea of You  2023.0           R           115.0
# 1      Kingdom of the Planet of the Apes  2023.0       PG-13           145.0
# 2                              Unfrosted  2023.0       PG-13            97.0
# ...

# %%
data.tail(10)
# Out:
#                                                  Poster  \
# 9990  https://m.media-amazon.com/images/M/MV5BNjFjYm...
# 9991  https://m.media-amazon.com/images/M/MV5BMjFkZG...
# 9992  https://m.media-amazon.com/images/M/MV5BMTUzOT...
# 9993  https://m.media-amazon.com/images/M/MV5BMzRkNj...
# 9994  https://m.media-amazon.com/images/M/MV5BNmRhZW...
# 9995  https://m.media-amazon.com/images/M/MV5BMzg5MW...
# 9996  https://m.media-amazon.com/images/M/MV5BYzA0ZG...
# 9997  https://m.media-amazon.com/images/M/MV5BM2U1Mj...
# 9998  https://m.media-amazon.com/images/M/MV5BMTAwOD...
# 9999  https://m.media-amazon.com/images/M/MV5BMmE4ZD...
#
#                                             Title    Year Certificate  \
# 9990                  The Masque of the Red Death  2020.0           A
# 9991                               Beyond the Law  2020.0         NaN
# 9992                     Kiss of the Spider Woman  2020.0         NaN
# ...

# %%
data.shape
# Out:
# (10000, 15)

# %%
print("number of rows ", data.shape[0])
print("number of columns ", data.shape[1])
# Out:
# number of rows  10000
# number of columns  15

# %%
#Information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Poster          10000 non-null  object
#  1   Title           10000 non-null  object
#  2   Year            9850 non-null   float64
#  3   Certificate     7370 non-null   object
#  4   Duration (min)  9664 non-null   float64
#  5   Genre           9993 non-null   object
#  6   Rating          9596 non-null   float64
#  7   Metascore       7555 non-null   float64
#  8   Director        9995 non-null   object
#  9   Cast            9961 non-null   object
#  10  Votes           9596 non-null   object
#  11  Description     10000 non-null  object
#  12  Review Count    9999 non-null   object
#  13  Review Title    9483 non-null   object
#  14  Review          9484 non-null   object
# dtypes: float64(4), object(11)
# memory usage: 1.1+ MB

# %%
#Check missing values
print("Any missing value?", data.isnull().values.any())
# Out:
# Any missing value? True

# %%
data.isnull().sum()
# Out:
# Poster               0
# Title                0
# Year               150
# Certificate       2630
# Duration (min)     336
# Genre                7
# Rating             404
# Metascore         2445
# Director             5
# Cast                39
# Votes              404
# Description          0
# Review Count         1
# Review Title       517
# Review             516
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing = data.isnull().sum()*100/len(data)
per_missing #percentage of missing values
# Out:
# Poster             0.00
# Title              0.00
# Year               1.50
# Certificate       26.30
# Duration (min)     3.36
# Genre              0.07
# Rating             4.04
# Metascore         24.45
# Director           0.05
# Cast               0.39
# Votes              4.04
# Description        0.00
# Review Count       0.01
# Review Title       5.17
# Review             5.16
# dtype: float64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Poster            0
# Title             0
# Year              0
# Certificate       0
# Duration (min)    0
# Genre             0
# Rating            0
# Metascore         0
# Director          0
# Cast              0
# Votes             0
# Description       0
# Review Count      0
# Review Title      0
# Review            0
# dtype: int64

# %%
#Check for duplicate data
drop_data= data.duplicated().any()

# %%
print("Are there any duplicate values? ",drop_data)
# Out:
# Are there any duplicate values?  False

# %%
##Overall Statistics about data set
data.describe()
# Out:
#               Year  Duration (min)       Rating    Metascore
# count  6404.000000     6404.000000  6404.000000  6404.000000
# mean   2006.289975      110.068395     6.548782    57.363991
# std      18.284315       19.477238     0.938561    17.629282
# min    1929.000000       55.000000     1.900000     1.000000
# 25%    1997.000000       97.000000     6.000000    45.000000
# 50%    2012.000000      107.000000     6.600000    57.000000
# 75%    2021.000000      119.000000     7.200000    70.000000
# max    2025.000000      321.000000     9.300000   100.000000

# %%
print(data["Votes"].dtype)
# Out:
# object

# %%
print(data['Votes'].unique())
# Out:
# ['28,744' '22,248' '18,401' ... '24,899' '16,078' '22,447']

# %%
data['Votes'] = pd.to_numeric(data['Votes'], errors='coerce') ##convert data type to float

# %%
print(data["Votes"].dtype)
# Out:
# float64

# %%
data.describe()
# Out:
#               Year  Duration (min)       Rating    Metascore       Votes
# count  6404.000000     6404.000000  6404.000000  6404.000000   32.000000
# mean   2006.289975      110.068395     6.548782    57.363991  411.906250
# std      18.284315       19.477238     0.938561    17.629282  302.458033
# min    1929.000000       55.000000     1.900000     1.000000   45.000000
# 25%    1997.000000       97.000000     6.000000    45.000000  205.250000
# 50%    2012.000000      107.000000     6.600000    57.000000  309.500000
# 75%    2021.000000      119.000000     7.200000    70.000000  514.500000
# max    2025.000000      321.000000     9.300000   100.000000  997.000000

# %%
data.describe(include='all')
# Out:
#                                                    Poster  Title         Year  \
# count                                                6404   6404  6404.000000
# unique                                               6404   6245          NaN
# top     https://m.media-amazon.com/images/M/MV5BMTAwOD...  Shaft          NaN
# freq                                                    1      3          NaN
# mean                                                  NaN    NaN  2006.289975
# std                                                   NaN    NaN    18.284315
# min                                                   NaN    NaN  1929.000000
# 25%                                                   NaN    NaN  1997.000000
# 50%                                                   NaN    NaN  2012.000000
# 75%                                                   NaN    NaN  2021.000000
# max                                                   NaN    NaN  2025.000000
#
# ...

# %%
print(data['Review Count'].unique())
# Out:
# ['166' '183' '333' ... '10' '1,706' '787']

# %%
print(data["Review Count"].dtype)
# Out:
# object

# %%
data['Review Count'] = pd.to_numeric(data['Review Count'], errors='coerce') ##Convert data type to float

# %%
print(data["Review Count"].dtype)
# Out:
# float64

# %%
data.describe()
# Out:
#               Year  Duration (min)       Rating    Metascore       Votes  \
# count  6404.000000     6404.000000  6404.000000  6404.000000   32.000000
# mean   2006.289975      110.068395     6.548782    57.363991  411.906250
# std      18.284315       19.477238     0.938561    17.629282  302.458033
# min    1929.000000       55.000000     1.900000     1.000000   45.000000
# 25%    1997.000000       97.000000     6.000000    45.000000  205.250000
# 50%    2012.000000      107.000000     6.600000    57.000000  309.500000
# 75%    2021.000000      119.000000     7.200000    70.000000  514.500000
# max    2025.000000      321.000000     9.300000   100.000000  997.000000
#
#        Review Count
# count   5982.000000
# mean     266.814610
# std      208.861191
# min        1.000000
# 25%      115.000000
# 50%      200.000000
# 75%      359.000000
# max      995.000000

# %%
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review'],
#       dtype='object')

# %%
#Movie name with duration >=180 mins
data[data['Duration (min)']>=180]['Title']
# Out:
# 33                                        Oppenheimer
# 60                                            Titanic
# 94                         Killers of the Flower Moon
# 116     The Lord of the Rings: The Return of the King
# 125                                  Schindler's List
# 137                           The Wolf of Wall Street
# 162                                    The Green Mile
# 177                                            Animal
# 222                                 Avengers: Endgame
# 293                                           Babylon
# 339                          Avatar: The Way of Water
# 358                             The Godfather Part II
# 419                       Once Upon a Time in America
# 518                                    Bound by Honor
# 529                                      Pearl Harbor
# 582                                    La vie d'Adèle
# 682                                         King Kong
# ...

# %%
##Year with the highest Average Voting (Year 2003)
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review'],
#       dtype='object')

# %%
data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 2003.0    958.000000
# 2005.0    893.000000
# 2018.0    736.000000
# 2017.0    688.500000
# 1995.0    621.000000
# 2022.0    562.000000
# 2023.0    495.800000
# 2013.0    452.000000
# 2019.0    441.000000
# 1968.0    389.000000
# 2010.0    329.000000
# 1990.0    308.000000
# 1981.0    253.000000
# 1991.0    253.000000
# 2002.0    215.000000
# 1934.0    191.000000
# 1983.0    169.000000
# 2007.0    153.000000
# 2024.0    139.333333
# 2021.0     73.000000
# 2014.0     61.000000
# 1929.0           NaN
# 1933.0           NaN
# 1945.0           NaN
# 1954.0           NaN
# 1955.0           NaN
# 1961.0           NaN
# 1964.0           NaN
# 1965.0           NaN
# 1966.0           NaN
# 1969.0           NaN
# 1971.0           NaN
# 1972.0           NaN
# 1973.0           NaN
# 1976.0           NaN
# 1977.0           NaN
# 1979.0           NaN
# 1985.0           NaN
# 1986.0           NaN
# 1988.0           NaN
# 1989.0           NaN
# 1992.0           NaN
# 1993.0           NaN
# ...

# %%
import matplotlib.pyplot as plt

sns.barplot(x='Year',y='Votes',data=data)
plt.title("Votes By Year")
plt.show()

# %%
#year with the highest metascore
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review'],
#       dtype='object')

# %%
data.groupby('Year')['Metascore'].mean().sort_values(ascending=False)
# Out:
# Year
# 1990.0    66.377778
# 1991.0    63.348837
# 2012.0    62.556122
# 2016.0    62.240566
# 1979.0    62.065217
# 1972.0    60.512821
# 2000.0    60.128205
# 2007.0    60.123529
# 2025.0    60.046296
# 1985.0    59.927928
# 1933.0    59.880000
# 2005.0    59.741497
# 1934.0    59.378378
# 2018.0    59.105263
# 1995.0    58.985714
# 2022.0    58.897959
# 2023.0    58.659359
# 1971.0    58.592593
# 1964.0    58.511628
# 1997.0    58.507353
# 2017.0    58.142132
# 2006.0    57.872222
# 1961.0    57.478261
# 2020.0    57.427273
# 1992.0    57.423077
# 1994.0    57.384615
# 2002.0    57.250000
# 1955.0    57.045455
# 2009.0    56.886792
# 2004.0    56.828571
# 2024.0    56.536842
# 1993.0    56.312500
# 2019.0    56.300654
# 1988.0    56.250000
# 1999.0    56.235294
# 2021.0    56.189602
# 1996.0    56.151724
# 2014.0    55.976852
# 2003.0    55.906250
# 1965.0    55.455882
# 1977.0    55.166667
# 2015.0    54.981818
# 1989.0    54.653061
# 1954.0    54.315789
# 1929.0    54.294118
# ...

# %%
sns.barplot(x='Year',y='Metascore',data=data)
plt.title("Metascore By Year")
plt.show()

# %%
#Average rating for each director
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review'],
#       dtype='object')

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Sam Yates             8.800
# Joaquim Dos Santos    8.600
# Roberto Benigni       8.600
# Charles Chaplin       8.500
# Tony Kaye             8.500
#                       ...
# Aaron Seltzer         2.800
# Jason Friedberg       2.625
# Edward Drake          2.500
# Roger Christian       2.500
# Tom Putnam            2.000
# Name: Rating, Length: 2623, dtype: float64

# %%
##Top 10 Lengthy Movies Title and Runtime
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review'],
#       dtype='object')

# %%
Top10_len=data.nlargest(10,'Duration (min)')[['Title', 'Duration (min)']]\
.set_index('Title')

# %%
Top10_len
# Out:
#                                    Duration (min)
# Title
# Gangs of Wasseypur                          321.0
# Novecento                                   317.0
# Zack Snyder's Justice League                242.0
# Gone with the Wind                          238.0
# Once Upon a Time in America                 229.0
# Lagaan: Once Upon a Time in India           224.0
# Heaven's Gate                               219.0
# Gods and Generals                           219.0
# Lawrence of Arabia                          218.0
# Ben-Hur                                     212.0

# %%
sns.barplot(x='Duration (min)', y=Top10_len.index,data=Top10_len)
# Out:
# <Axes: xlabel='Duration (min)', ylabel='Title'>

# %%
##Number Of mivies Per Year
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review'],
#       dtype='object')

# %%
data['Year'].value_counts()
# Out:
# Year
# 2023.0    593
# 2024.0    380
# 2021.0    327
# 2022.0    245
# 2020.0    220
# 2014.0    216
# 2016.0    212
# 2017.0    197
# 2012.0    196
# 2002.0    184
# 2006.0    180
# 2007.0    170
# 2015.0    165
# 2019.0    153
# 2005.0    147
# 1996.0    145
# 1995.0    140
# 1997.0    136
# 1999.0    136
# 2018.0    133
# 2013.0    127
# 2008.0    112
# 1985.0    111
# 2025.0    108
# 2009.0    106
# 2004.0    105
# 2001.0    101
# 1989.0     98
# 2011.0     81
# 1965.0     68
# 1994.0     65
# 2003.0     64
# 1993.0     64
# 1981.0     55
# 2010.0     55
# 1992.0     52
# 1998.0     49
# 1979.0     46
# 1990.0     45
# 1991.0     43
# 1964.0     43
# 1988.0     40
# 1972.0     39
# 2000.0     39
# 1954.0     38
# 1934.0     37
# 1968.0     33
# 1945.0     31
# 1969.0     30
# 1971.0     27
# 1933.0     25
# 1973.0     25
# 1976.0     24
# 1961.0     23
# 1983.0     23
# 1955.0     22
# 1966.0     22
# 1977.0     18
# 1986.0     18
# 1929.0     17
# Name: count, dtype: int64

# %%
sns.countplot(x='Year',data=data)
plt.title("Number of Movies per year")
plt.show()

# %%
##Top 10 Highest Rated movie titkes and its directors
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review'],
#       dtype='object')

# %%
top10_len=data.nlargest(10,'Rating')[['Title', 'Rating']]\
.set_index('Title')

# %%
top10_len
# Out:
#                                                    Rating
# Title
# The Shawshank Redemption                              9.3
# The Godfather                                         9.2
# The Dark Knight                                       9.0
# The Lord of the Rings: The Return of the King         9.0
# Schindler's List                                      9.0
# 12 Angry Men                                          9.0
# The Godfather Part II                                 9.0
# The Lord of the Rings: The Fellowship of the Ring     8.9
# Pulp Fiction                                          8.9
# Inception                                             8.8

# %%
import seaborn as sns
top10_len = top10_len.reset_index()
print(top10_len.columns)
# Out:
# Index(['Title', 'Rating'], dtype='object')

# %%
top10_len = top10_len.merge(data[['Title','Director']], on='Title', how='left')

# %%
sns.barplot(
    x='Rating',
    y='Title',
    data=top10_len,
    hue='Director',dodge=False
)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)

# %%
## Classification of movies based on ratings[Excellent, Good and Average]
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review'],
#       dtype='object')

# %%
def rating(rating):
    if rating >= 7.0:
        return "Excellent"
    elif rating >= 6.0:
        return "Good"
    else:
        return "Average"

# %%
data['rating_cat']=data['Rating'].apply(rating)

# %%
data.head()
# Out:
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1  https://m.media-amazon.com/images/M/MV5BZGI4NT...
# 2  https://m.media-amazon.com/images/M/MV5BZjIyOT...
# 3  https://m.media-amazon.com/images/M/MV5BMjA5Zj...
# 4  https://m.media-amazon.com/images/M/MV5BNTk1MT...
#
#                                Title    Year Certificate  Duration (min)  \
# 0                    The Idea of You  2023.0           R           115.0
# 1  Kingdom of the Planet of the Apes  2023.0       PG-13           145.0
# 2                          Unfrosted  2023.0       PG-13            97.0
# 3                       The Fall Guy  2023.0       PG-13           126.0
# 4                        Challengers  2023.0           R           131.0
#
#                         Genre  Rating  Metascore           Director  \
# 0      Comedy, Drama, Romance     6.4       67.0  Michael Showalter
# ...

# %%
## Number of Action Movies
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review', 'rating_cat'],
#       dtype='object')

# %%
data['Genre'].dtype
# Out:
# dtype('O')

# %%
len(data[data['Genre'].str.contains('Action',case=False)])
# Out:
# 1739

# %%
##Unique values from genre
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review', 'rating_cat'],
#       dtype='object')

# %%
data['Genre']
# Out:
# 0            Comedy, Drama, Romance
# 1         Action, Adventure, Sci-Fi
# 2        Biography, Comedy, History
# 3             Action, Comedy, Drama
# 4             Drama, Romance, Sport
#                    ...
# 9990                  Drama, Horror
# 9993                   Crime, Drama
# 9994    Adventure, Biography, Drama
# 9995         Drama, Family, Romance
# 9998        Biography, Crime, Drama
# Name: Genre, Length: 6404, dtype: object

# %%
list1 = []
for value in data['Genre']:
    list1.append(value.split(','))

# %%
list1
# Out:
# [['Comedy', ' Drama', ' Romance'],
#  ['Action', ' Adventure', ' Sci-Fi'],
#  ['Biography', ' Comedy', ' History'],
#  ['Action', ' Comedy', ' Drama'],
#  ['Drama', ' Romance', ' Sport'],
#  ['Horror', ' Thriller'],
#  ['Action', ' Adventure', ' Thriller'],
#  ['Comedy', ' Romance'],
#  ['Action', ' Drama', ' War'],
#  ['Action', ' Adventure', ' Drama'],
#  ['Action', ' Adventure', ' Sci-Fi'],
#  ['Action', ' Adventure', ' Drama'],
#  ['Adventure', ' Comedy', ' Fantasy'],
#  ['Action', ' Adventure', ' Crime'],
#  ['Crime', ' Drama', ' Mystery'],
#  ['Horror'],
#  ['Action', ' Adventure', ' Drama'],
#  ['Action', ' Thriller'],
#  ['Horror'],
#  ['Action', ' Adventure', ' Fantasy'],
#  ['Comedy', ' Drama', ' Romance'],
#  ['Action', ' Horror', ' Thriller'],
#  ['Action', ' Comedy', ' Thriller'],
#  ['Action', ' Adventure', ' Fantasy'],
#  ['Drama', ' Romance'],
#  ['Action', ' Drama', ' Sci-Fi'],
#  ['Biography', ' Drama', ' History'],
#  ['Action', ' Adventure', ' Sci-Fi'],
# ...

# %%
one_d=[]
for item in list1:
   for item1 in item:
      one_d.append(item1)

# %%
one_d
# Out:
# ['Comedy',
#  ' Drama',
#  ' Romance',
#  'Action',
#  ' Adventure',
#  ' Sci-Fi',
#  'Biography',
#  ' Comedy',
#  ' History',
#  'Action',
#  ' Comedy',
#  ' Drama',
#  'Drama',
#  ' Romance',
#  ' Sport',
#  'Horror',
#  ' Thriller',
#  'Action',
#  ' Adventure',
#  ' Thriller',
#  'Comedy',
#  ' Romance',
#  'Action',
#  ' Drama',
#  ' War',
#  'Action',
#  ' Adventure',
#  ' Drama',
#  'Action',
#  ' Adventure',
#  ' Sci-Fi',
#  'Action',
#  ' Adventure',
#  ' Drama',
#  'Adventure',
#  ' Comedy',
#  ' Fantasy',
#  'Action',
#  ' Adventure',
#  ' Crime',
#  'Crime',
#  ' Drama',
#  ' Mystery',
#  'Horror',
#  'Action',
#  ' Adventure',
#  ' Drama',
#  'Action',
#  ' Thriller',
#  'Horror',
#  'Action',
#  ' Adventure',
#  ' Fantasy',
#  'Comedy',
#  ' Drama',
#  ' Romance',
#  'Action',
#  ' Horror',
#  ' Thriller',
#  'Action',
#  ' Comedy',
#  ' Thriller',
#  'Action',
#  ' Adventure',
#  ' Fantasy',
#  'Drama',
#  ' Romance',
#  'Action',
#  ' Drama',
#  ' Sci-Fi',
# ...

# %%
uni_list=[]
for item in one_d:
    if item not in uni_list:
        uni_list.append(item)

# %%
uni_list
# Out:
# ['Comedy',
#  ' Drama',
#  ' Romance',
#  'Action',
#  ' Adventure',
#  ' Sci-Fi',
#  'Biography',
#  ' Comedy',
#  ' History',
#  'Drama',
#  ' Sport',
#  'Horror',
#  ' Thriller',
#  ' War',
#  'Adventure',
#  ' Fantasy',
#  ' Crime',
#  'Crime',
#  ' Mystery',
#  ' Horror',
#  ' Music',
#  'Animation',
#  ' Action',
#  ' Family',
#  ' Musical',
#  ' Biography',
#  ' Western',
#  'Fantasy',
#  'Thriller',
#  'Mystery',
#  'Sci-Fi',
#  'Documentary',
#  'Music',
#  ' Film-Noir',
#  'Film-Noir',
#  'Romance',
#  ' Animation',
#  'History',
#  'Family']

# %%
##Number of films for each genre were made
data.columns
# Out:
# Index(['Poster', 'Title', 'Year', 'Certificate', 'Duration (min)', 'Genre',
#        'Rating', 'Metascore', 'Director', 'Cast', 'Votes', 'Description',
#        'Review Count', 'Review Title', 'Review', 'rating_cat'],
#       dtype='object')

# %%
one_d=[]
for item in list1:
   for item1 in item:
      one_d.append(item1)

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Comedy': 1476,
#          ' Drama': 2203,
#          ' Romance': 1001,
#          'Action': 1651,
#          ' Adventure': 945,
#          ' Sci-Fi': 540,
#          'Biography': 428,
#          ' Comedy': 769,
#          ' History': 207,
#          'Drama': 1178,
#          ' Sport': 156,
#          'Horror': 359,
#          ' Thriller': 1118,
#          ' War': 110,
#          'Adventure': 385,
#          ' Fantasy': 494,
#          ' Crime': 744,
#          'Crime': 460,
#          ' Mystery': 717,
#          ' Horror': 480,
#          ' Music': 197,
#          'Animation': 342,
#          ' Action': 88,
#          ' Family': 347,
#          ' Musical': 69,
#          ' Biography': 79,
#          ' Western': 62,
#          'Fantasy': 37,
#          'Thriller': 14,
#          'Mystery': 26,
#          'Sci-Fi': 5,
#          'Documentary': 36,
#          'Music': 1,
#          ' Film-Noir': 6,
#          'Film-Noir': 1,
#          'Romance': 2,
# ...
